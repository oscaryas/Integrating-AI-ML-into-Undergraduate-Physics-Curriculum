# %% [markdown]
# #Prerequisites:

# %% [markdown]
# If you don't know what Objects, Classes, Inheritance or Constructors are please do this first then move on:

# %% [markdown]
# # Module:

# %% [markdown]
# ## Objectives

# %% [markdown]
# 1. Introduction to Pytorch
# 2. How to build models in Pytorch
# 3. How to do Grad Descent with Pytorch
# 4. Introduce Nodes and Weights

# %% [markdown]
# Before we begin please change your runtime type

# %% [markdown]
# ### Changing Runtime Type

# %% [markdown]
# If you look at the image below you will select the arrow pointing down right next to the arrow pointing up near the top right of your screen.

# %% [markdown]
# <div>
# <img src="
# https://drive.google.com/uc?id=1EAMj_OSHcKVnwcuvL3oT1IOTu9UkP5mE" width="500"/>
# </div>

# %% [markdown]
# You will then select change runtime type and click T4 GPU. This will speed up the downloading and computation process.

# %% [markdown]
# GPU's are better for doing matrix multiplication than CPU's so they are better at doing computation. That's the reason we will be using GPU's as our runtime type.

# %% [markdown]
# ### Importing Dependencies

# %%
# %%capture
# %pip install numpy scipy pandas scikit-learn matplotlib torch

# %%
import numpy as np
import gdown
import random
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score

# %%
# !gdown https://drive.google.com/uc?id=1Uozz9Nr-Ajg1Nv9LVueKUZaXhy5S2Ijb
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Uozz9Nr-Ajg1Nv9LVueKUZaXhy5S2Ijb
# To: /content/statics.csv
# 100% 45.6k/45.6k [00:00<00:00, 91.8MB/s]

# %%
df = pd.read_csv('/content/statics.csv')
df.head()
# Out:
#    Unnamed: 0  labels  force applied  frictional coefficient
# 0           0     0.0       2.728552                0.778298
# 1           1     0.0       3.824200                0.892255
# 2           2     0.0       1.298377                0.245112
# 3           3     0.0       2.104434                0.207469
# 4           4     0.0       1.360571                0.094685

# %%
# @title Label Distribution

from matplotlib import pyplot as plt
df['labels'].plot(kind='hist', bins=20, title='labels')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Brief Refresher Code and Concepts

# %% [markdown]
# ![kms.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The governing equation here is $$N = mg$$ $$f = μN$$ $$f \leq F$$
#
# where N is normal force, m is mass, g is gravitational constant, $μ$ is frictional coefficient and F is horizontal applied force.
#
# We know that if applied force is greater than frictional force, than the object will move. I will simulate this data below.
#
# I've labeled objects that stayed stationary as 0 and objects that got moved as 1.

# %%
#Extracts labels, forces, and friction applied data and converts into numpy arrays

labels = df['labels'].to_numpy()
forces = df['force applied'].to_numpy()
friction_coeffs = df['frictional coefficient'].to_numpy()

# %%
#Reshapes labels, forces, and friction into (1000,1) instead of (1000,)
labels = labels.reshape((1000,1))
forces = forces.reshape((1000,1))
friction_coeffs = friction_coeffs.reshape((1000,1))

#Creates features numpy array which has dimension (1000,2)
features = np.hstack((forces, friction_coeffs))

# %%
#Scatter plot of the stationary and moved objects with respect of friciton and
#Force applied .

plt.scatter(forces, friction_coeffs, c = labels)
plt.xlabel("Force Applied (N)")
plt.ylabel("Frictional Coefficient (Unitless)")
plt.title("Scatter Plot of Movement of Objects Under Varied Magnitudes of Force Applied and Frictional Coefficients")
move_patch = mpatches.Patch(color=plt.cm.viridis(1.0), label='Moves')
stationary_patch = mpatches.Patch(color=plt.cm.viridis(0.0), label='Stationary')
plt.legend(handles=[stationary_patch, move_patch])
plt.show()

# %% [markdown]
# The ultimate goal is to determine the decision boundary which seperates the stationary objects and the non stationary objects

# %% [markdown]
# ## Pytorch vs Tensorflow

# %% [markdown]
# You might be asking why PyTorch, why not TensorFlow?

# %% [markdown]
# <div>
# <img src="
# https://cdn.prod.website-files.com/67a1e6de2f2eab2e125f8b9a/67be0ec8aef316bdeea12871_percentage_repo_2023.png" width="500"/>
# </div>

# %% [markdown]
# This is the number of papers that use each framework. In 2018, around 25% of papers used tensorflow, 25% used PyTorch and 50% used some other altnerative. In 2022, around 50% used PyTorch. So the trends indicate that PyTorch will be more beneficial in industry and in research. So we will be using PyTorch. Ultimately the underlying ML Principles regardless of framework.

# %% [markdown]
# ## Typical PyTorch Practices

# %% [markdown]
# I will implement a LinearRegressionModel and explain the process.
#
# **You will then implement a LogisticRegressionModel**

# %% [markdown]
# ### Torch Tensors

# %% [markdown]
# Torch works with torch.tensors. In a similar vain to how numpy works with only np.arrays and not python lists, if you are using the torch library, it only works with torch tensors. (To convert numpy to torch tensors use torch.from_numpy())

# %%
#Use train_test_split to split features and labels into training data
#and testing data. Use a 20% test, 80% train split.
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2)

#Convert x_train, x_test, y_train, y_test using torch.from_numpy() function
x_train = torch.from_numpy(x_train)
x_test = torch.from_numpy(x_test)
y_train = torch.from_numpy(y_train)
y_test = torch.from_numpy(y_test)

# %%
#Print out the x_train, x_test, y_train, y_test type here. Use type() function.
print(type(x_train), type(x_test), type(y_train), type(y_test))
# Out:
# <class 'torch.Tensor'> <class 'torch.Tensor'> <class 'torch.Tensor'> <class 'torch.Tensor'>

# %% [markdown]
# ### Step 1: Define Model Architecture

# %% [markdown]
# You have to define your model. This is done by creating your own model class that inherits from nn.Module

# %% [markdown]
# I will write code for how to create a linear regression model and explain what each piece states

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(2, 1)

    def forward(self, input_data):
        return self.linear(input_data)

model = LinearRegressionModel()

# %% [markdown]
# <pre> class LinearRegressionModel(nn.Module): </pre>

# %% [markdown]
# If you want to create a LinearRegression Model you have to define a LinearRegression Model class. The LinearRegressionModel inherits properties from nn.Module class.

# %% [markdown]
#     def __init__(self):
#         super().__init__()

# %% [markdown]
# This is the constructor. It creates your model object. super() is called since there is a constructor in nn.Module and will initialize all the internal tracking. The gradient tracking, the parameter tracking, the layer tracking.

# %% [markdown]
#         self.linear = nn.Linear(2, 1)

# %% [markdown]
# This creates a single linear transformation. It basically is a weighted sum. So it multiplies weights to your two input values and adds bias resulting in your output.
#
# $$w_1x_1+w_2x_2+b$$
#
# nn.Linear has three important arguments:
#
# nn.Linear(input_dimension, output_dimension, bias = True)
# By default, bias is true. If you don't want to add bias to your output, you can set bias = False.
#
# The following diagram or computation graph or perceptron is to help visualize what is occuring:

# %% [markdown]
# <div>
# <img src="
# https://drive.google.com/uc?id=19PQsx0W1n_CxTAFOoNjoMwfwYXH9OsJj" width="500"/>
# </div>

# %% [markdown]
# Each edge has a weight associated with it. The output is the weighted sum of the inputs $x_1$, $x_2$. Force Applied and Friction Coefficients are the inputs. There is a small bias term attached to the output node.

# %% [markdown]
#     def forward(self, input_data):
#         return self.linear(input_data)

# %% [markdown]
# This is called the forward pass. It is just passing the input to the output through mathematics we've set up. We can set this up like this since nn.Linear is actually a callable (more or less a function), so self.linear is also a callable.
#
# You will input your training data into forward().

# %% [markdown]
#     model = LinearRegressionModel()

# %% [markdown]
# Creates an instance of the LinearRegressionModel class

# %% [markdown]
# ### Step 2: Define Loss and Optimizer Algorithm

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# Defines that the "criterion" or loss is the Mean Squared Error.
#
# The optimization algorithm you picked was the stochastic gradient descent. It's just gradient descent but instead of computing loss for the entire dataset you pick a point at random and compute the loss, then you update the entire weights.

# %% [markdown]
# ### Step 3: Train Model

# %% [markdown]
# You will probably face an error here because the type of Tensor you are working with might not be compatible for calculation. When training your model you must make sure that all Tensors are the same type. Try running the code below, then convert all your x_train, x_test, y_train, and y_test into floats using .float() method.

# %%
for epoch in range(100):
    preds = model(x_train)
    loss = criterion(preds, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch} Loss: {loss.item():.4f}")
# Out:
# Epoch 0 Loss: 4.7219
# Epoch 10 Loss: 269560053760.0000
# Epoch 20 Loss: 16714938880199755825152.0000
# Epoch 30 Loss: 1036464137322897805115284038615040.0000
# Epoch 40 Loss: inf
# Epoch 50 Loss: inf
# Epoch 60 Loss: inf
# Epoch 70 Loss: inf
# Epoch 80 Loss: nan
# Epoch 90 Loss: nan

# %%
#Fix the Tensor Type here (Use .float())
x_train = x_train.float()
x_test = x_test.float()
y_train = y_train.float()
y_test = y_test.float()

# %% [markdown]
# Go back up and run the previous cell

# %% [markdown]
#     preds = model(x_train)
#     loss = criterion(preds, y_train)

# %% [markdown]
# You are basically sending your input data and calculating the loss between the predictions and y training data

# %% [markdown]
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# %% [markdown]
# optimizer.zero_grad sets your gradient back to 0. If you don't clear then the magnitude or direction of the gradient might change.
#
# Example:
#
# Round 1
# $$\frac{dL}{dw_1} = 5$$
#
# Round 2
# $$\frac{dL}{dw_1} = 5+(-2) = 3$$
#
# which is in the completely wrong direction. It depends on the scenario when to use optimizer.zero_grad.
#
# loss.backward computes the gradients for you.
#
# optimizer.step updates the parameters you had.

# %% [markdown]
# ### Step 4: Evaluate Model

# %%
predictions = model(x_test)
predictions = predictions.round()

# %%
#This won't work so ignore the error. Explaining what detach() and numpy() are.
print(accuracy_score(predictions.detach().numpy(), y_test.detach().numpy()))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py:399: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2177221975.py in <cell line: 0>()
#       1 #This won't work so ignore the error. Explaining what detach() and numpy() are.
# ----> 2 print(accuracy_score(predictions.detach().numpy(), y_test.detach().numpy()))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 227     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     228     check_consistent_length(y_true, y_pred, sample_weight)
#     229
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      97     xp, _ = get_namespace(y_true, y_pred)
#      98     check_consistent_length(y_true, y_pred)
# ---> 99     type_true = type_of_target(y_true, input_name="y_true")
#     100     type_pred = type_of_target(y_pred, input_name="y_pred")
#     101
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in type_of_target(y, input_name, raise_unknown)
#     415         data = y.data if issparse(y) else y
#     416         if xp.any(data != xp.astype(data, int)):
# --> 417             _assert_all_finite(data, input_name=input_name)
#     418             return "continuous" + suffix
#     419
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input y_true contains NaN.

# %% [markdown]
# You have to use .detach() because PyTorch internally sets up computation graphs, where everything is connected. So in order to do calculations with Tensor you've put through the model, you have to detach them then do calculations. Numpy() is just for accuracy_score since it

# %% [markdown]
# If you ever see NaN, you are kinda screwed but this is expected here cuz linear regression should since it can't handle predicting labels

# %% [markdown]
# ### Step 5: Graph Decision Boundary

# %%
weights = model.linear.weight.detach().numpy()
bias = model.linear.bias.detach().numpy()

# %%
weights, bias
# Out:
# (array([[nan, nan]], dtype=float32), array([nan], dtype=float32))

# %% [markdown]
# If you see nan, of inf values you messed up somewhere and need to troubleshoot

# %%
def plotting(w):
    xmin, xmax = 0, 8
    ymin, ymax = 0, 1

    xd = np.array([xmin, xmax])
    m = -w[0:, 0]/w[0:, 1]
    yd = m*xd
    plt.plot(xd ,yd, 'r', lw = 4, ls = '--')
    plt.scatter(forces, friction_coeffs, c = labels)
    plt.xlabel("Force Applied (N)")
    plt.ylabel("Frictional Coefficient (Unitless)")
    plt.title("Scatter Plot of Movement of Objects Under Varied Magnitudes of Force Applied and Frictional Coefficients")
    move_patch = mpatches.Patch(color=plt.cm.viridis(1.0), label='Moves')
    stationary_patch = mpatches.Patch(color=plt.cm.viridis(0.0), label='Stationary')
    plt.legend(handles=[stationary_patch, move_patch])
    plt.show()
    print(f"""The predicted mass is:{1/m}
The actual mass was 14.7""")

# %%
plotting(weights)
# Out:
# The predicted mass is:[nan]
# The actual mass was 14.7

# %% [markdown]
# Obviously LinearRegression here won't work. But you will implement LogisticRegression below:
#
# Hint: When you return compute forward you might want to wrap the output in sigmoidal function. You might have to change forward method/function
#
# Hint: The loss function for sigmoidal function is different than the MSELoss

# %% [markdown]
# ## Your Turn:

# %% [markdown]
# ### Step 1: Define Model Architecture

# %%
#Define LogisticRegressionModel Class.
class LogisticRegressionModel(nn.Module):

    #Define Constructor Here:
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(2, 1)

    #Define forward here:
    def forward(self, x):
        #You are gonna wrap self.linear(x) with what activation function?
        return torch.sigmoid(self.linear(x))

#Instantiate LogisticRegressionModel() and set it to a model variable
model = LogisticRegressionModel()

# %% [markdown]
# ### Step 2: Loss and Optimizer

# %%
#criterion shouldn't be MSELoss. What was the loss function for sigmoid?
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# ### Step 3: Train Model

# %% [markdown]
# The number of epochs is up to you. Accuracy score should be around 90%

# %%
#The number of epochs you do (i.e.) convergence conditions is up to you.
for epoch in range(10000):

    #predictions from x_train data
    preds = model(x_train)
    loss = criterion(preds, y_train)

    #Sets optimizer so it won't accumulate gradients
    optimizer.zero_grad()

    #Calculate gradient descent
    loss.backward()

    #Update weights
    optimizer.step()

    #Print loss:
    if epoch % 10 == 0:
        print(f"Epoch {epoch} Loss: {loss.item():.4f}")
# Out:
# Epoch 0 Loss: 0.9316
# Epoch 10 Loss: 0.5817
# Epoch 20 Loss: 0.5581
# Epoch 30 Loss: 0.5374
# Epoch 40 Loss: 0.5191
# Epoch 50 Loss: 0.5028
# Epoch 60 Loss: 0.4883
# Epoch 70 Loss: 0.4753
# Epoch 80 Loss: 0.4635
# Epoch 90 Loss: 0.4527
# Epoch 100 Loss: 0.4429
# Epoch 110 Loss: 0.4339
# Epoch 120 Loss: 0.4256
# Epoch 130 Loss: 0.4179
# Epoch 140 Loss: 0.4108
# Epoch 150 Loss: 0.4041
# Epoch 160 Loss: 0.3979
# Epoch 170 Loss: 0.3921
# Epoch 180 Loss: 0.3865
# Epoch 5870 Loss: 0.1197
# Epoch 5880 Loss: 0.1196
# Epoch 5890 Loss: 0.1195
# Epoch 5900 Loss: 0.1195
# Epoch 5910 Loss: 0.1194
# Epoch 5920 Loss: 0.1193
# Epoch 5930 Loss: 0.1192
# Epoch 5940 Loss: 0.1192
# Epoch 5950 Loss: 0.1191
# Epoch 5960 Loss: 0.1190
# Epoch 5970 Loss: 0.1190
# Epoch 5980 Loss: 0.1189
# Epoch 5990 Loss: 0.1188
# Epoch 6000 Loss: 0.1187
# Epoch 6010 Loss: 0.1187
# Epoch 6020 Loss: 0.1186
# Epoch 6030 Loss: 0.1185
# Epoch 6040 Loss: 0.1185
# Epoch 6050 Loss: 0.1184
# Epoch 6060 Loss: 0.1183
# Epoch 6070 Loss: 0.1183
# Epoch 6080 Loss: 0.1182
# Epoch 6090 Loss: 0.1181
# Epoch 6100 Loss: 0.1180
# Epoch 6110 Loss: 0.1180
# Epoch 6120 Loss: 0.1179
# Epoch 6130 Loss: 0.1178
# Epoch 6140 Loss: 0.1178
# Epoch 6150 Loss: 0.1177
# Epoch 6160 Loss: 0.1176
# Epoch 6170 Loss: 0.1176
# Epoch 6180 Loss: 0.1175
# Epoch 6190 Loss: 0.1174
# Epoch 6200 Loss: 0.1174
# Epoch 6210 Loss: 0.1173
# Epoch 6220 Loss: 0.1172
# Epoch 6230 Loss: 0.1172
# Epoch 6240 Loss: 0.1171
# Epoch 6250 Loss: 0.1170
# Epoch 6260 Loss: 0.1170
# Epoch 6270 Loss: 0.1169
# Epoch 6280 Loss: 0.1168
# Epoch 6290 Loss: 0.1168
# Epoch 6300 Loss: 0.1167
# Epoch 6310 Loss: 0.1166
# Epoch 6320 Loss: 0.1166
# Epoch 6330 Loss: 0.1165
# Epoch 6340 Loss: 0.1164
# Epoch 6350 Loss: 0.1164
# Epoch 6360 Loss: 0.1163
# Epoch 6370 Loss: 0.1162
# Epoch 6380 Loss: 0.1162
# Epoch 6390 Loss: 0.1161
# Epoch 6400 Loss: 0.1161
# Epoch 6410 Loss: 0.1160
# Epoch 6420 Loss: 0.1159
# Epoch 6430 Loss: 0.1159
# Epoch 6440 Loss: 0.1158
# Epoch 6450 Loss: 0.1157
# Epoch 6460 Loss: 0.1157
# Epoch 6470 Loss: 0.1156
# Epoch 6480 Loss: 0.1155
# Epoch 6490 Loss: 0.1155
# Epoch 6500 Loss: 0.1154
# Epoch 6510 Loss: 0.1154
# Epoch 6520 Loss: 0.1153
# Epoch 6530 Loss: 0.1152
# Epoch 6540 Loss: 0.1152
# Epoch 6550 Loss: 0.1151
# Epoch 6560 Loss: 0.1150
# Epoch 6570 Loss: 0.1150
# Epoch 6580 Loss: 0.1149
# Epoch 6590 Loss: 0.1149
# Epoch 6600 Loss: 0.1148
# Epoch 6610 Loss: 0.1147
# Epoch 6620 Loss: 0.1147
# Epoch 6630 Loss: 0.1146
# Epoch 6640 Loss: 0.1146
# Epoch 6650 Loss: 0.1145
# Epoch 6660 Loss: 0.1144
# Epoch 6670 Loss: 0.1144
# Epoch 6680 Loss: 0.1143
# Epoch 6690 Loss: 0.1143
# Epoch 6700 Loss: 0.1142
# Epoch 6710 Loss: 0.1141
# Epoch 6720 Loss: 0.1141
# Epoch 6730 Loss: 0.1140
# Epoch 6740 Loss: 0.1140
# Epoch 6750 Loss: 0.1139
# Epoch 6760 Loss: 0.1138
# Epoch 6770 Loss: 0.1138
# Epoch 6780 Loss: 0.1137
# Epoch 6790 Loss: 0.1137
# Epoch 6800 Loss: 0.1136
# Epoch 6810 Loss: 0.1135
# Epoch 6820 Loss: 0.1135
# Epoch 6830 Loss: 0.1134
# Epoch 6840 Loss: 0.1134
# Epoch 6850 Loss: 0.1133
# Epoch 6860 Loss: 0.1132
# Epoch 6870 Loss: 0.1132
# Epoch 6880 Loss: 0.1131
# Epoch 6890 Loss: 0.1131
# Epoch 6900 Loss: 0.1130
# Epoch 6910 Loss: 0.1130
# Epoch 6920 Loss: 0.1129
# Epoch 6930 Loss: 0.1128
# Epoch 6940 Loss: 0.1128
# Epoch 6950 Loss: 0.1127
# Epoch 6960 Loss: 0.1127
# Epoch 6970 Loss: 0.1126
# Epoch 6980 Loss: 0.1126
# Epoch 6990 Loss: 0.1125
# Epoch 7000 Loss: 0.1124
# Epoch 7010 Loss: 0.1124
# Epoch 7020 Loss: 0.1123
# Epoch 7030 Loss: 0.1123
# Epoch 7040 Loss: 0.1122
# Epoch 7050 Loss: 0.1122
# Epoch 7060 Loss: 0.1121
# Epoch 7070 Loss: 0.1121
# Epoch 7080 Loss: 0.1120
# Epoch 7090 Loss: 0.1119
# Epoch 7100 Loss: 0.1119
# Epoch 7110 Loss: 0.1118
# Epoch 7120 Loss: 0.1118
# Epoch 7130 Loss: 0.1117
# Epoch 7140 Loss: 0.1117
# Epoch 7150 Loss: 0.1116
# Epoch 7160 Loss: 0.1116
# Epoch 7170 Loss: 0.1115
# Epoch 7180 Loss: 0.1114
# Epoch 7190 Loss: 0.1114
# Epoch 7200 Loss: 0.1113
# Epoch 7210 Loss: 0.1113
# Epoch 7220 Loss: 0.1112
# Epoch 7230 Loss: 0.1112
# Epoch 7240 Loss: 0.1111
# Epoch 7250 Loss: 0.1111
# Epoch 7260 Loss: 0.1110
# Epoch 7270 Loss: 0.1110
# Epoch 7280 Loss: 0.1109
# Epoch 7290 Loss: 0.1109
# Epoch 7300 Loss: 0.1108
# Epoch 7310 Loss: 0.1107
# Epoch 7320 Loss: 0.1107
# Epoch 7330 Loss: 0.1106
# Epoch 7340 Loss: 0.1106
# Epoch 7350 Loss: 0.1105
# Epoch 7360 Loss: 0.1105
# Epoch 7370 Loss: 0.1104
# Epoch 7380 Loss: 0.1104
# Epoch 7390 Loss: 0.1103
# Epoch 7400 Loss: 0.1103
# Epoch 7410 Loss: 0.1102
# Epoch 7420 Loss: 0.1102
# Epoch 7430 Loss: 0.1101
# Epoch 7440 Loss: 0.1101
# Epoch 7450 Loss: 0.1100
# Epoch 7460 Loss: 0.1100
# Epoch 7470 Loss: 0.1099
# Epoch 7480 Loss: 0.1099
# Epoch 7490 Loss: 0.1098
# Epoch 7500 Loss: 0.1098
# Epoch 7510 Loss: 0.1097
# Epoch 7520 Loss: 0.1097
# Epoch 7530 Loss: 0.1096
# Epoch 7540 Loss: 0.1096
# Epoch 7550 Loss: 0.1095
# Epoch 7560 Loss: 0.1095
# Epoch 7570 Loss: 0.1094
# Epoch 7580 Loss: 0.1094
# Epoch 7590 Loss: 0.1093
# Epoch 7600 Loss: 0.1093
# Epoch 7610 Loss: 0.1092
# Epoch 7620 Loss: 0.1092
# Epoch 7630 Loss: 0.1091
# Epoch 7640 Loss: 0.1091
# Epoch 7650 Loss: 0.1090
# Epoch 7660 Loss: 0.1090
# Epoch 7670 Loss: 0.1089
# Epoch 7680 Loss: 0.1089
# Epoch 7690 Loss: 0.1088
# Epoch 7700 Loss: 0.1088
# Epoch 7710 Loss: 0.1087
# Epoch 7720 Loss: 0.1087
# Epoch 7730 Loss: 0.1086
# Epoch 7740 Loss: 0.1086
# Epoch 7750 Loss: 0.1085
# Epoch 7760 Loss: 0.1085
# Epoch 7770 Loss: 0.1084
# Epoch 7780 Loss: 0.1084
# Epoch 7790 Loss: 0.1083
# Epoch 7800 Loss: 0.1083
# Epoch 7810 Loss: 0.1082
# Epoch 7820 Loss: 0.1082
# Epoch 7830 Loss: 0.1081
# Epoch 7840 Loss: 0.1081
# Epoch 7850 Loss: 0.1080
# Epoch 7860 Loss: 0.1080
# Epoch 7870 Loss: 0.1079
# Epoch 7880 Loss: 0.1079
# Epoch 7890 Loss: 0.1078
# Epoch 7900 Loss: 0.1078
# Epoch 7910 Loss: 0.1077
# Epoch 7920 Loss: 0.1077
# Epoch 7930 Loss: 0.1076
# Epoch 7940 Loss: 0.1076
# Epoch 7950 Loss: 0.1075
# Epoch 7960 Loss: 0.1075
# Epoch 7970 Loss: 0.1075
# Epoch 7980 Loss: 0.1074
# Epoch 7990 Loss: 0.1074
# Epoch 8000 Loss: 0.1073
# Epoch 8010 Loss: 0.1073
# Epoch 8020 Loss: 0.1072
# Epoch 8030 Loss: 0.1072
# Epoch 8040 Loss: 0.1071
# Epoch 8050 Loss: 0.1071
# Epoch 8060 Loss: 0.1070
# Epoch 8070 Loss: 0.1070
# Epoch 8080 Loss: 0.1069
# Epoch 8090 Loss: 0.1069
# Epoch 8100 Loss: 0.1068
# Epoch 8110 Loss: 0.1068
# Epoch 8120 Loss: 0.1068
# Epoch 8130 Loss: 0.1067
# Epoch 8140 Loss: 0.1067
# Epoch 8150 Loss: 0.1066
# Epoch 8160 Loss: 0.1066
# Epoch 8170 Loss: 0.1065
# Epoch 8180 Loss: 0.1065
# Epoch 8190 Loss: 0.1064
# Epoch 8200 Loss: 0.1064
# Epoch 8210 Loss: 0.1063
# Epoch 8220 Loss: 0.1063
# Epoch 8230 Loss: 0.1063
# Epoch 8240 Loss: 0.1062
# Epoch 8250 Loss: 0.1062
# Epoch 8260 Loss: 0.1061
# Epoch 8270 Loss: 0.1061
# Epoch 8280 Loss: 0.1060
# Epoch 8290 Loss: 0.1060
# Epoch 8300 Loss: 0.1059
# Epoch 8310 Loss: 0.1059
# Epoch 8320 Loss: 0.1059
# Epoch 8330 Loss: 0.1058
# Epoch 8340 Loss: 0.1058
# Epoch 8350 Loss: 0.1057
# Epoch 8360 Loss: 0.1057
# Epoch 8370 Loss: 0.1056
# Epoch 8380 Loss: 0.1056
# Epoch 8390 Loss: 0.1056
# Epoch 8400 Loss: 0.1055
# Epoch 8410 Loss: 0.1055
# Epoch 8420 Loss: 0.1054
# Epoch 8430 Loss: 0.1054
# Epoch 8440 Loss: 0.1053
# Epoch 8450 Loss: 0.1053
# Epoch 8460 Loss: 0.1052
# Epoch 8470 Loss: 0.1052
# Epoch 8480 Loss: 0.1052
# Epoch 8490 Loss: 0.1051
# Epoch 8500 Loss: 0.1051
# Epoch 8510 Loss: 0.1050
# Epoch 8520 Loss: 0.1050
# Epoch 8530 Loss: 0.1049
# Epoch 8540 Loss: 0.1049
# Epoch 8550 Loss: 0.1049
# Epoch 8560 Loss: 0.1048
# Epoch 8570 Loss: 0.1048
# Epoch 8580 Loss: 0.1047
# Epoch 8590 Loss: 0.1047
# Epoch 8600 Loss: 0.1047
# Epoch 8610 Loss: 0.1046
# Epoch 8620 Loss: 0.1046
# Epoch 8630 Loss: 0.1045
# Epoch 8640 Loss: 0.1045
# Epoch 8650 Loss: 0.1044
# Epoch 8660 Loss: 0.1044
# Epoch 8670 Loss: 0.1044
# Epoch 8680 Loss: 0.1043
# Epoch 8690 Loss: 0.1043
# Epoch 8700 Loss: 0.1042
# Epoch 8710 Loss: 0.1042
# Epoch 8720 Loss: 0.1041
# Epoch 8730 Loss: 0.1041
# Epoch 8740 Loss: 0.1041
# Epoch 8750 Loss: 0.1040
# Epoch 8760 Loss: 0.1040
# Epoch 8770 Loss: 0.1039
# Epoch 8780 Loss: 0.1039
# Epoch 8790 Loss: 0.1039
# Epoch 8800 Loss: 0.1038
# Epoch 8810 Loss: 0.1038
# Epoch 8820 Loss: 0.1037
# Epoch 8830 Loss: 0.1037
# Epoch 8840 Loss: 0.1037
# Epoch 8850 Loss: 0.1036
# Epoch 8860 Loss: 0.1036
# Epoch 8870 Loss: 0.1035
# Epoch 8880 Loss: 0.1035
# Epoch 8890 Loss: 0.1035
# Epoch 8900 Loss: 0.1034
# Epoch 8910 Loss: 0.1034
# Epoch 8920 Loss: 0.1033
# Epoch 8930 Loss: 0.1033
# Epoch 8940 Loss: 0.1033
# Epoch 8950 Loss: 0.1032
# Epoch 8960 Loss: 0.1032
# Epoch 8970 Loss: 0.1031
# Epoch 8980 Loss: 0.1031
# Epoch 8990 Loss: 0.1031
# Epoch 9000 Loss: 0.1030
# Epoch 9010 Loss: 0.1030
# Epoch 9020 Loss: 0.1029
# Epoch 9030 Loss: 0.1029
# Epoch 9040 Loss: 0.1029
# Epoch 9050 Loss: 0.1028
# Epoch 9060 Loss: 0.1028
# Epoch 9070 Loss: 0.1027
# Epoch 9080 Loss: 0.1027
# Epoch 9090 Loss: 0.1027
# Epoch 9100 Loss: 0.1026
# Epoch 9110 Loss: 0.1026
# Epoch 9120 Loss: 0.1025
# Epoch 9130 Loss: 0.1025
# Epoch 9140 Loss: 0.1025
# Epoch 9150 Loss: 0.1024
# Epoch 9160 Loss: 0.1024
# Epoch 9170 Loss: 0.1024
# Epoch 9180 Loss: 0.1023
# Epoch 9190 Loss: 0.1023
# Epoch 9200 Loss: 0.1022
# Epoch 9210 Loss: 0.1022
# Epoch 9220 Loss: 0.1022
# Epoch 9230 Loss: 0.1021
# Epoch 9240 Loss: 0.1021
# Epoch 9250 Loss: 0.1020
# Epoch 9260 Loss: 0.1020
# Epoch 9270 Loss: 0.1020
# Epoch 9280 Loss: 0.1019
# Epoch 9290 Loss: 0.1019
# Epoch 9300 Loss: 0.1019
# Epoch 9310 Loss: 0.1018
# Epoch 9320 Loss: 0.1018
# Epoch 9330 Loss: 0.1017
# Epoch 9340 Loss: 0.1017
# Epoch 9350 Loss: 0.1017
# Epoch 9360 Loss: 0.1016
# Epoch 9370 Loss: 0.1016
# Epoch 9380 Loss: 0.1016
# Epoch 9390 Loss: 0.1015
# Epoch 9400 Loss: 0.1015
# Epoch 9410 Loss: 0.1014
# Epoch 9420 Loss: 0.1014
# Epoch 9430 Loss: 0.1014
# Epoch 9440 Loss: 0.1013
# Epoch 9450 Loss: 0.1013
# Epoch 9460 Loss: 0.1013
# Epoch 9470 Loss: 0.1012
# Epoch 9480 Loss: 0.1012
# Epoch 9490 Loss: 0.1012
# Epoch 9500 Loss: 0.1011
# Epoch 9510 Loss: 0.1011
# Epoch 9520 Loss: 0.1010
# Epoch 9530 Loss: 0.1010
# Epoch 9540 Loss: 0.1010
# Epoch 9550 Loss: 0.1009
# Epoch 9560 Loss: 0.1009
# Epoch 9570 Loss: 0.1009
# Epoch 9580 Loss: 0.1008
# Epoch 9590 Loss: 0.1008
# Epoch 9600 Loss: 0.1008
# Epoch 9610 Loss: 0.1007
# Epoch 9620 Loss: 0.1007
# Epoch 9630 Loss: 0.1006
# Epoch 9640 Loss: 0.1006
# Epoch 9650 Loss: 0.1006
# Epoch 9660 Loss: 0.1005
# Epoch 9670 Loss: 0.1005
# Epoch 9680 Loss: 0.1005
# Epoch 9690 Loss: 0.1004
# Epoch 9700 Loss: 0.1004
# Epoch 9710 Loss: 0.1004
# Epoch 9720 Loss: 0.1003
# Epoch 9730 Loss: 0.1003
# Epoch 9740 Loss: 0.1003
# Epoch 9750 Loss: 0.1002
# Epoch 9760 Loss: 0.1002
# Epoch 9770 Loss: 0.1001
# Epoch 9780 Loss: 0.1001
# Epoch 9790 Loss: 0.1001
# Epoch 9800 Loss: 0.1000
# Epoch 9810 Loss: 0.1000
# Epoch 9820 Loss: 0.1000
# Epoch 9830 Loss: 0.0999
# Epoch 9840 Loss: 0.0999
# Epoch 9850 Loss: 0.0999
# Epoch 9860 Loss: 0.0998
# Epoch 9870 Loss: 0.0998
# Epoch 9880 Loss: 0.0998
# Epoch 9890 Loss: 0.0997
# Epoch 9900 Loss: 0.0997
# Epoch 9910 Loss: 0.0997
# Epoch 9920 Loss: 0.0996
# Epoch 9930 Loss: 0.0996
# Epoch 9940 Loss: 0.0996
# Epoch 9950 Loss: 0.0995
# Epoch 9960 Loss: 0.0995
# Epoch 9970 Loss: 0.0994
# Epoch 9980 Loss: 0.0994
# Epoch 9990 Loss: 0.0994

# %% [markdown]
# ### Step 4: Evaluate Model

# %%
#Evaluate model on test data
model.evaluate()
with torch.no_grad():
  preds = model(x_test)
  preds = preds.round()
  print(accuracy_score(y_test.detach().numpy(), preds.detach().numpy()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-720961677.py in <cell line: 0>()
#       1 #Evaluate model on test data
# ----> 2 model.evaluate()
#       3 with torch.no_grad():
#       4   preds = model(x_test)
#       5   preds = preds.round()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### Step 5: Plot Decision Boundary

# %%
#Return weights and biases
w = model.linear.weight.detach().numpy()
b = model.linear.bias.detach().numpy()

# %%
#Use plotting function():
plotting(w)
# Out:
# The predicted mass is:[13.457153]
# The actual mass was 14.7

# %% [markdown]
# # Exploring Torch Library

# %% [markdown]
# Since we remade let's just start printing everything we created to get a better sense of what we just made.

# %%
#Print x_train, x_train.shape,  x_train.dtype, is_leaf, and grad

# %%
print(x_train)
print(x_train.shape)
print(x_train.dtype)
print(x_train.is_leaf)
print(x_train.grad)
print(x_train.device)
# Out:
# tensor([[4.8813, 0.2492],
#         [1.2930, 0.0722],
#         [0.5875, 0.7905],
#         ...,
#         [3.6512, 0.0703],
#         [1.4829, 0.6171],
#         [0.5348, 0.6849]])
# torch.Size([800, 2])
# torch.float32
# True
# None
# cpu

# %% [markdown]
# When you create a neural network, Pytorch automatically creates a computation graph for you and stores information about the each weight and bias. A leaf indicates that you are part of this graph.
#
# That is why you have to use .detach() if

# %% [markdown]
# <div>
# <img src="https://media5.datahacker.rs/2021/01/54-1.jpg"
#      width="500"/>
# </div>

# %% [markdown]
# Let's print out your model now

# %%
print(model)
# Out:
# LogisticRegressionModel(
#   (linear): Linear(in_features=2, out_features=1, bias=True)
# )

# %% [markdown]
# The class name of the model.
#
# A tree-like listing of all its submodules (layers).
#
# For each submodule: its type (Linear, Conv2d, etc.), input/output sizes if known, kernel sizes, strides, and other parameters.
#
# If the model has nested modules, you see indentation reflecting the hierarchy.

# %%
print(model.state_dict())
print(list(model.parameters()))
# Out:
# OrderedDict({'linear.weight': tensor([[  1.1166, -15.0266]]), 'linear.bias': tensor([-0.5514])})
# [Parameter containing:
# tensor([[  1.1166, -15.0266]], requires_grad=True), Parameter containing:
# tensor([-0.5514], requires_grad=True)]

# %% [markdown]
# model.state_dict shows you each weight that the model will learn. So in our case we had two weights in one layer and a bias term in one layer.
#
# model.paramters() is a generator, which creates a Tensor objects. Parameters store the tensor itself.

# %%
print(optimizer)

# %% [markdown]
# *   Optimizer name (SGD, Adam, etc.).
# *   Parameter groups similar to what we implemented for power law. different hyperparameters for different weights.
# *   Hyperparameters for that group: lr, momentum, betas, eps, weight_decay, etc.
# *   For multi–param groups, you’d see Parameter Group 1, Parameter Group 2, etc.

# %%
print(loss)

# %% [markdown]
# loss tells you what grad_fn you used.
